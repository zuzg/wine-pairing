# %% [markdown]
# ## Flavor Graph pairing

# %%
import pandas as pd
from gensim.models import Word2Vec

from src.data_preprocessing.flavor_graph_preprocessing import (
    load_embedding,
    split_unanonimize_nodes,
    pair_item_with_category,
)
from src.pairing_rules.generate_pairings import generate_single_pairing

# %%
FLAVOR_GRAPH_PATH = '../data/flavor_graph/FlavorGraph+CSP-embedding_WP-metapath_300-dim_0.0025-initial_lr_3-window_size_10-iterations_5-min_count-_False-isCSP_0.0001-CSPcoef.pickle'
NODES_PATH = '../data/flavor_graph/nodes_with_wine.csv'

# %%
fg_embed_dict_ids = load_embedding(FLAVOR_GRAPH_PATH)
fg_embed_dict_ids.keys()
# Out:
# dict_keys(['7198', '960', '7518', '1089', '7243', '5582', '7560', '4600', '7556', '1895', '7205', '4620', '7678', '86', '8193', '7228', '1664', '7523', '7223', '4444', '7471', '4635', '7513', '7307', '5526', '8223', '4150', '7559', '429', '8328', '8378', '5173', '8380', '2947', '7360', '4733', '7576', '7281', '4928', '7773', '328', '7683', '3840', '7142', '7493', '962', '8437', '4885', '994', '4021', '7315', '5579', '4835', '1138', '7423', '3565', '22', '6787', '1429', '5834', '1504', '8334', '6004', '5747', '7439', '423', '374', '5345', '7366', '175', '4370', '5205', '8315', '1129', '5556', '6091', '8677', '1005', '6109', '8332', '3860', '5968', '2167', '6079', '3743', '5929', '5121', '4052', '8782', '6631', '286', '2198', '58', '7830', '4331', '8312', '4744', '2945', '2188', '7399', '1453', '3587', '8723', '88', '93', '4494', '8405', '640', '3720', '8329', '1263', '5770', '7644', '345', '3092', '3572', '7726', '5190', '1479', '3782', '7453', '972', '4309', '7286', '6367', '1670', '6763', '5028', '4116', '5192', '7178', '5285', '6574', '148', '8347', '5262', '6775', '6599', '5292', '282', '6441', '8830', '3973', '6803', '8810', '2331', '1389', '6171', '662', '8593', '5039', '1041', '8612', '4438', '3714', '2793', '8339', '991', '153', '1786', '8570', '2790', '1631', '7818', '1426', '480', '4292', '3526', '2588', '6212', '7153', '223', '3383', '6477', '6821', '841', '4763', '7117', '6051', '4636', '5759', '7583', '6782', '5905', '273', '5939', '6131', '8306', '159', '5818', '7825', '1430', '2366', '2396', '5228', '4935', '4572', '2368', '6083', '1595', '4577', '3492', '7835', '5885', '5267', '8689', '879', '1111', '7335', '6032', '4472', '6229', '8712', '707', '6717', '8695', '1775', '1027', '8302', '4716', '5930', '781', '7440', '729', '754', '6424', '7839', '6408', '5569', '8146', '7167', '7821', '4701', '7433', '6031', '7143', '5016', '7599', '7438', '4615', '7145', '504', '7115', '8381', '2223', '7826', '1018', '7682', '8377', '8199', '8196', '3489', '7208', '7043', '7183', '6756', '7106', '7151', '7383', '1845', '7460', '6045', '6299', '7787', '213', '2490', '5809', '7776', '5652', '7137', '2364', '6227', '1254', '1773', '4804', '163', '7991', '871', '7109', '5119', '3128', '7231', '5519', '2480', '4545', '547', '2939', '7665', '4937', '3016', '5676', '7170', '3882', '5330', '5168', '6315', '7598', '5027', '265', '7344', '4381', '8543', '4431', '3161', '7218', '3986', '7751', '4966', '5000', '5608', '7226', '5558', '7569', '1458', '1325', '7272', '2443', '4251', '7152', '6547', '595', '7293', '4737', '6818', '4710', '6172', '4622', '517', '1508', '1682', '7105', '2352', '1009', '3290', '7296', '1919', '656', '8221', '8040', '5080', '6508', '8244', '7013', '4340', '6627', '7165', '5431', '3320', '1319', '5823', '8383', '3025', '814', '8308', '2393', '2164', '6739', '4084', '7473', '6864', '7245', '2836', '1718', '6266', '3503', '8310', '5707', '7129', '4469', '2312', '1783', '7455', '2914', '747', '7463', '1588', '5334', '6145', '7925', '7535', '8275', '8125', '7144', '5967', '8449', '3717', '7434', '1395', '8431', '709', '823', '7695', '7154', '4575', '7502', '8346', '5650', '3562', '7722', '7138', '805', '7229', '1083', '7428', '7622', '1488', '3162', '1003', '1590', '1014', '1625', '4809', '453', '3834', '111', '7332', '2517', '3133', '2152', '1794', '710', '4204', '7157', '4172', '1967', '8220', '1444', '7224', '4659', '6157', '7611', '7087', '441', '6545', '6098', '537', '7575', '5714', '3096', '1768', '3548', '5587', '7432', '3837', '518', '2210', '6779', '7859', '5328', '3125', '2506', '1563', '2239', '300', '2068', '4264', '485', '3465', '5108', '7387', '2380', '3426', '1635', '8834', '5404', '2256', '2981', '8807', '8388', '5529', '8819', '6303', '461', '3851', '8486', '786', '4961', '7134', '2381', '2200', '1742', '7579', '4109', '6813', '8421', '254', '7246', '5668', '5872', '4460', '2980', '1636', '7551', '2890', '4158', '7817', '3632', '3376', '2757', '5743', '6380', '6371', '2390', '8441', '4287', '3169', '11 ...

# %%
fg_embed_dict_ids['7198'].shape
# Out:
# (300,)

# %%
nodes_df = pd.read_csv(NODES_PATH)
nodes_df.head()
# Out:
#    node_id                    name  id   node_type  is_hub
# 0        0       1%_fat_buttermilk NaN  ingredient  no_hub
# 1        1   1%_fat_cottage_cheese NaN  ingredient  no_hub
# 2        3               10%_cream NaN  ingredient  no_hub
# 3        4               100%_bran NaN  ingredient  no_hub
# 4        5  10_inch_flour_tortilla NaN  ingredient  no_hub

# %%
fg_embed_dict = split_unanonimize_nodes(nodes_df, fg_embed_dict_ids)
fg_embed_dict.keys()
# Out:
# dict_keys(['compound', 'ingredient', 'wine'])

# %%
for key in fg_embed_dict.keys():
    print(f"Category: {key.upper()}, number of items: {len(fg_embed_dict[key])}")
    print(f"Exemplary items: {list(fg_embed_dict[key].keys())[:5]}\n")
# Out:
# Category: COMPOUND, number of items: 1633
# Exemplary items: ['eugenol', '3-methylthiopropanol', 'Linalool', 'Beta-Phellandrene', 'Methyl_Isobutyrate']
#
# Category: INGREDIENT, number of items: 6653
# Exemplary items: ['canola_oil', 'cheese', 'sage', 'papaya', 'dill']
#
# Category: WINE, number of items: 107
# Exemplary items: ['Cabernet Sauvignon, Barossa,  South Australia,  Australia', 'Red Blends, Red Blends,  Southern Oregon,  Oregon,  US', 'Bordeaux-style Red Blend, Listrac-Médoc,  Bordeaux,  France', 'Grillo, Italian White, Sicilia,  Sicily & Sardinia,  Italy', 'White Blend, Etna,  Sicily & Sardinia,  Italy']

# %%
# EXEMPLARY EMBEDDING
category = 'ingredient'
name = 'mango'

fg_embed_dict[category][name]
# Out:
# array([-0.2981921 , -0.02563435, -0.2505978 ,  0.10616672, -0.02561186,
#         0.06016891, -0.07432453, -0.18450247,  0.16229858,  0.08904628,
#        -0.04630957,  0.05405298,  0.1683048 , -0.06777766,  0.05493566,
#        -0.03493505, -0.0533022 , -0.2643112 ,  0.08056065,  0.03207704,
#         0.11187352, -0.1739578 , -0.12155879,  0.07098675,  0.16595621,
#        -0.06562718,  0.19446406, -0.06749196, -0.11292143,  0.05721229,
#        -0.10526533, -0.09164085,  0.09912632, -0.02498809,  0.3281356 ,
#         0.20079322, -0.10567888,  0.12356447, -0.09444073,  0.07963233,
#         0.13190752,  0.06271315,  0.10611369, -0.07464299,  0.02290803,
#        -0.19762658,  0.0491326 , -0.31233507, -0.14628816, -0.16454068,
#         0.09274351,  0.3000756 , -0.05545472,  0.04565948, -0.0009815 ,
#        -0.0800032 , -0.2817043 ,  0.3964886 , -0.18808995,  0.14148882,
#         0.2190107 ,  0.02620921,  0.13576405, -0.02985151, -0.19656987,
#         0.0196165 , -0.11587851, -0.20072562,  0.06812003,  0.14500861,
#        -0.21360558, -0.12112509, -0.28355947, -0.1437736 , -0.03669449,
#        -0.20565824,  0.08749633,  0.04249975,  0.06195009,  0.0066718 ,
#        -0.16773045, -0.10870308,  0.08249701, -0.0544807 ,  0.04451292,
#        -0.04353796,  0.2722164 , -0.05458281,  0.3023342 , -0.04463949,
#        -0.17346963,  0.11343236, -0.20257847, -0.11377768, -0.04013312,
#        -0.07366361, -0.01696642, -0.04636287, -0.04695748, -0.24919151,
#        -0.08217685, -0.04217644, -0.18988098, -0.09046409,  0.07176419,
#         0.0878915 ,  0.13682272,  0.3078387 , -0.0363794 , -0.13464183,
#         0.1692367 ,  0.01442681,  0.07271671, -0.09628246, -0.02041449,
#         0.08123197,  0.14347634, -0.11600567, -0.07941761, -0.06732776,
#         0.05812846, -0.07801699, -0.01695128, -0.04553697,  0.15129827,
#         0.10399935, -0.22223063,  0.08204253, -0.163839  , -0.12328701,
#        -0.07590957, -0.34082237, -0.12253805,  0.0846032 , -0.18001914,
#         0.12559089,  0.01466815, -0.17343153, -0.01010014, -0.07696865,
#        -0.04321529, -0.0900429 ,  0.17281646, -0.1843997 , -0.16669758,
#        -0.00173423, -0.02903786,  0.21729821, -0.00853012, -0.05778634,
#         0.06150935, -0.02865228,  0.04419559, -0.09887644,  0.06795569,
#         0.0821519 ,  0.09801151, -0.0522802 , -0.05967629,  0.16552022,
#         0.06610018, -0.05397295,  0.00387363, -0.21800359, -0.10001004,
#         0.02569247,  0.0241422 ,  0.10257313, -0.06420245,  0.02657204,
#         0.12999701, -0.03270711, -0.17578648, -0.18335404, -0.07663304,
#         0.13063405,  0.09747574,  0.00171309,  0.08042575, -0.22151026,
#        -0.3070057 ,  0.22998258, -0.13091242, -0.05988524, -0.00741391,
#         0.07176518, -0.04503832,  0.14763638,  0.12875515, -0.08617735,
#        -0.04560561,  0.12230265,  0.19596076,  0.31287342,  0.15244344,
#         0.10455362, -0.03813761,  0.19136532, -0.06784564, -0.22913578,
#         0.10351118,  0.10757656,  0.01432098, -0.20541024, -0.19691509,
#         0.08929311, -0.01244208, -0.08310901,  0.17298734,  0.11469003,
#        -0.08939991, -0.14457898,  0.13768525,  0.29571667, -0.02185193,
#        -0.06433713,  0.17254987, -0.07530037, -0.252349  ,  0.08295318,
#        -0.00612928,  0.15220058,  0.02279014,  0.1620731 ,  0.23337649,
#        -0.1408275 , -0.06884258,  0.08287704,  0.07487368,  0.03466345,
#        -0.19972013, -0.02539534, -0.13202147,  0.18809418,  0.03216187,
#         0.01952423, -0.06483167, -0.04495684, -0.26956534,  0.07301062,
#        -0.24222459, -0.01134807, -0.09307537,  0.24352229, -0.20349693,
#         0.08389831, -0.05185936,  0.10151131, -0.12599228, -0.06549207,
#        -0.2684464 ,  0.14611025, -0.09937674, -0.02534654, -0.20570152,
#         0.1209792 , -0.09078857, -0.02956734,  0.01614843,  0.04485372,
#        -0.05964052, -0.14038187, -0.08163578, -0.20686251, -0.09442704,
#        -0.01760231,  0.06300849, -0.09152704,  0.33738407, -0.21470785,
#        -0.07613999, -0.0481623 , -0.18033847,  0.10169587,  0.12931658,
#        -0.12556157,  0.16976605,  0.24368723,  0.00324357,  0.00635532,
#         0.00254236, -0.14085749,  0.07719905,  0.23953885,  0.24296801,
#        -0.04809234,  0.28139985, -0.03816373,  0.24438716,  0.05441286,
#        -0.22132684, -0.03367447, -0.14549729, -0.01026372,  0.04650496,
#         0.08610377,  0.07620019,  0.17057762,  0.05463161,  0.05848539],
#       dtype=float32)

# %% [markdown]
# ### Pair food with wine

# %%
item = "burrito"
# item = 'White Blend, Etna,  Sicily & Sardinia,  Italy'
# item = 'Phlorizin'
top_n = 5

# %% [markdown]
# #### Regular pairings

# %%
wine_vectors = pd.read_csv("../data/wine_aromas_nonaromas.csv", index_col="Unnamed: 0")
descriptor_frequencies = pd.read_csv("../data/wine_variety_descriptors.csv", index_col="index")
wine_word2vec_model = Word2Vec.load("../data/word2vec.bin")
word_vectors = wine_word2vec_model.wv
food_nonaroma_infos = pd.read_csv("../data/food_nonaroma_info.csv", index_col="Unnamed: 0")

generate_single_pairing(item, wine_vectors, word_vectors, food_nonaroma_infos, top_n)
# Out:
# ['Bordeaux-style Red Blend, , Stellenbosch,  South Africa',
#  'Bordeaux-style Red Blend, Lussac Saint-Émilion,  Bordeaux,  France',
#  'Malbec-Cabernet Sauvignon, Bordeaux-style Red Blend, Mendoza,  Mendoza Province,  Argentina',
#  'Cabernet Sauvignon, , Judean Hills,  Israel',
#  'Bordeaux-style Red Blend, Margaux,  Bordeaux,  France']

# %% [markdown]
# #### FlavorGraph pairings

# %%
pair_item_with_category(item, fg_embed_dict, top_n = top_n)
# Out:
# ['Bordeaux-style Red Blend, Listrac-Médoc,  Bordeaux,  France',
#  'Grillo, Italian White, Sicilia,  Sicily & Sardinia,  Italy',
#  'Red Blends, Red Blends,  Southern Oregon,  Oregon,  US',
#  'Bordeaux-style Red Blend, Mendoza,  Mendoza Province,  Argentina',
#  'Viognier,  Sonoma,  California,  US']

# %%
pair_item_with_category(item, fg_embed_dict, 'ingredient', top_n = top_n)
# Out:
# ['salsa', 'black_olive', 'sour_cream', 'meatloaf', 'lingonberry']

# %%
pair_item_with_category(item, fg_embed_dict, 'compound', top_n = top_n)
# Out:
# ['CID_644104',
#  'thiamine',
#  'Heptanoic_Acid',
#  'betaine',
#  'Thiamine_Hydrochloride']

# %% [markdown]
# Multi-ingredeint pairings

# %%
multiple_items = 'Ginger +cinnamon'
top_n = 5

# %%
pair_item_with_category(multiple_items, fg_embed_dict, top_n = top_n)
# Out:
# ['Riesling, Niagara Peninsula,  Ontario,  Canada',
#  'Nebbiolo, Piedmont,  Piedmont,  Italy',
#  'Cabernet Sauvignon, , Aconcagua Valley,  Chile',
#  'Riesling,  Long Island,  New York,  US',
#  'Bordeaux-style Red Blend, Castillon Côtes de Bordeaux,  Bordeaux,  France']

# %%
pair_item_with_category(multiple_items, fg_embed_dict, 'ingredient', top_n = top_n)
# Out:
# ['nutmeg',
#  'dried_orange_peel',
#  'black_tea_bag',
#  'goji_berry',
#  'light_molasses']

# %%
pair_item_with_category(multiple_items, fg_embed_dict, 'compound', top_n = top_n)
# Out:
# ['gingerol',
#  'cis-Methylisoeugenol',
#  'Acetyleugenol',
#  '(5xi,7xi,10xi)-eudesma-4(14),11-diene',
#  'carnosol']
